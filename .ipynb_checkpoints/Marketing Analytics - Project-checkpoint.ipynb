# %%
import pandas as pd
from pandas import Series,DataFrame
# %pylab inline
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
filename = 'Retail Transactions Data.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
df_retail = pd.read_csv(filename,parse_dates=['InvoiceDate'], date_parser=dateparse,encoding='cp1252')

# %% [markdown]
# #### Removing rows with CustomerID blank

# %%
## Removing rows with CustomerID blank
print (df_retail.shape)

df_retail = df_retail.drop(df_retail[df_retail['CustomerID'].isnull()].index)

print (df_retail.shape)

# %% [markdown]
# #### Adding a column "Total  Price" of the transaction

# %%
## adding a column total price of the transaction
df_retail['Total Price'] = df_retail['UnitPrice']* df_retail['Quantity']

# %% [markdown]
# #### Removing entries from Decemeber 2011

# %%
## removing entries from december 2011

df_retail = df_retail.drop(df_retail[(df_retail['InvoiceDate'].dt.year == 2011) & (df_retail['InvoiceDate'].dt.month == 12)].index)
print (df_retail.shape)

# %% [markdown]
# #### Aggregating the details at Invoice level

# %%
## Invoice level details

def dow(dt):
    return dt.day_name()

df_invoice = df_retail.groupby(['InvoiceNo','CustomerID', 'Country','InvoiceDate'])[['Total Price', 'Quantity']].sum()
print (df_invoice.shape)
df_invoice = pd.DataFrame(df_invoice.to_records())
df_invoice['Invoice_Month'] = df_invoice['InvoiceDate'].dt.strftime("%B")
df_invoice['DayofWeek'] = df_invoice['InvoiceDate'].map(dow)
print (df_invoice.shape)
df_invoice.head(5)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Number of Orders by Month

# %%
## Orders by Month

df_monthly = df_invoice.groupby('Invoice_Month')[['InvoiceNo']].count()
df_monthly = pd.DataFrame(df_monthly.to_records())
month_order = ["January", "February", "March", "April", "May", "June", "July","August", "September", "October", "November", "December"]
df_monthly.set_index("Invoice_Month").loc[month_order]['InvoiceNo'].plot(kind = 'bar')
xlabel('Month Name')
ylabel('Number of Orders')
title('Distribution of Orders by Month')

# %% [markdown]
# #### Orders by Day of the Week

# %%
## Orders by Day of the Week

df_dow = df_invoice.groupby('DayofWeek')[['InvoiceNo']].count()
df_dow = pd.DataFrame(df_dow.to_records())
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df_dow.set_index("DayofWeek").loc[day_order]['InvoiceNo'].plot(kind = 'bar')
xlabel('Day of the Week')
ylabel('Number of Orders')
title('Distribution of Orders by Day of the Week')

# %% [markdown]
# #### Orders by Country

# %%
## Orders by Country

df_country = df_invoice.groupby('Country')[['InvoiceNo']].count()
df_country = pd.DataFrame(df_country.to_records())
df_country.set_index("Country")['InvoiceNo'].plot(kind = 'bar')
xlabel('Country')
ylabel('Number of Orders')
title('Distribution of Orders by Country')

# %% [markdown]
# #### Aggregating Data at Customer Level for every month

# %%
## Getting data at a customer level
## customer month firstorder of month last order of month total sales in month

## Sales and Quantity by Month
df_customer_sales = df_invoice.groupby(['CustomerID','Invoice_Month'])[['Total Price','Quantity']].sum()
df_customer_sales = pd.DataFrame(df_customer_sales.to_records())
#print (df_customer_sales.head(5))
#print (df_customer_sales.shape)

## Orders by Month
df_customer_orders = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceNo']].count()
df_customer_orders = pd.DataFrame(df_customer_orders.to_records())
#print (df_customer_orders.head(5))
#print (df_customer_orders.shape)

## First order in a Month
df_customer_monthlyfirst = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceDate']].min()
df_customer_monthlyfirst = pd.DataFrame(df_customer_monthlyfirst.to_records())
#print (df_customer_monthlyfirst.head(5))
#print (df_customer_monthlyfirst.shape)

## Last order in a Month
df_customer_monthlylast = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceDate']].max()
df_customer_monthlylast = pd.DataFrame(df_customer_monthlylast.to_records())
#print (df_customer_monthlylast.head(5))
#print (df_customer_monthlylast.shape)

df_customer = df_customer_sales.merge(df_customer_monthlyfirst, on = ['CustomerID','Invoice_Month'],suffixes = ['_left','_right'])
#print (df_customer.head(5))
df_customer = df_customer.merge(df_customer_monthlylast, on = ['CustomerID','Invoice_Month'],suffixes = ['_firstorder','_lastorder'])
#print (df_customer.head(5))
df_customer = df_customer.merge(df_customer_orders, on = ['CustomerID','Invoice_Month'],suffixes = ['_firstorder','_lastorder'])
#print (df_customer.head(5))




df_customer.rename(columns = {'InvoiceDate_firstorder':'FirstOrder','InvoiceDate_lastorder':'LastOrder','InvoiceNo':'Ordercount'}, inplace = True) 
print (df_customer.head(5))
print (df_customer.shape)

# %% [markdown]
# #### Getting the RFM details of the customer

# %%
from datetime import datetime

def recency(dt):
    dys = (datetime.strptime('2011-12-01', "%Y-%m-%d") - dt).days
    return dys


## RFM for 12 months - December 2010 - November 2011

## monetory value
df_customer_m = df_customer.groupby(['CustomerID'])[['Total Price']].sum()
df_customer_m = pd.DataFrame(df_customer_m.to_records())
df_customer_m.rename(columns = {'Total Price':'Monetory'}, inplace = True) 
#print (df_customer_m.head(5))


## frequency
df_customer_f = df_customer.groupby(['CustomerID'])[['Ordercount']].sum()
df_customer_f = pd.DataFrame(df_customer_f.to_records())
df_customer_f.rename(columns = {'Ordercount':'Frequency'}, inplace = True) 
#print (df_customer_f.head(5))

## recency

df_customer_r = df_customer.groupby(['CustomerID'])[['LastOrder']].max()
df_customer_r = pd.DataFrame(df_customer_r.to_records())
df_customer_r['Recency'] = df_customer_r['LastOrder'].map(recency)
df_customer_r = df_customer_r.drop(columns=['LastOrder'])
#print (df_customer_r.head(5))

## getting RFM together

df_customer_rfm = df_customer_m.merge(df_customer_f,on = ['CustomerID'])
df_customer_rfm = df_customer_rfm.merge(df_customer_r,on = ['CustomerID'])
print (df_customer_rfm.head(5))

# %% [markdown]
# #### Getting all important customer attributes together

# %%
def getdays(s):
    return (s.days+1)

## Getting Aggregated values at customer level

## Total Sales, Orders, Items for the year
df_customer_ov = df_customer.groupby(['CustomerID'])[['Total Price','Quantity','Ordercount']].sum()
df_customer_ov = pd.DataFrame(df_customer_ov.to_records())
#print (df_customer_ov.head(5))

## First Order of Customer
df_customer_first = df_customer.groupby(['CustomerID'])[['FirstOrder']].min()
df_customer_first = pd.DataFrame(df_customer_first.to_records())
#print (df_customer_first.head(5))

## Last Order of Customer
df_customer_last = df_customer.groupby(['CustomerID'])[['LastOrder']].max()
df_customer_last = pd.DataFrame(df_customer_last.to_records())
#print (df_customer_last.head(5))

## Number of active months
df_customer_months = df_customer.groupby(['CustomerID'])[['Invoice_Month']].count()
df_customer_months = pd.DataFrame(df_customer_months.to_records())
df_customer_months.rename(columns = {'Invoice_Month':'ActiveMonths'}, inplace = True) 
#print (df_customer_months.head(5))


## Days between first and last order
df_customer_daysbetween = df_customer_first.merge(df_customer_last, on = 'CustomerID')
df_customer_daysbetween['ActiveDays'] = (df_customer_daysbetween['LastOrder'] - df_customer_daysbetween['FirstOrder']).map(getdays)
#print (df_customer_daysbetween.head(5))

# %%
## Getting all important customer attributes together

df_customer_att = df_customer_ov.merge(df_customer_months, on = 'CustomerID')
df_customer_att = df_customer_att.merge(df_customer_daysbetween, on ='CustomerID')
df_customer_att = df_customer_att.drop(columns=['LastOrder','FirstOrder'])
df_customer_att = df_customer_att.merge(df_customer_r,on = 'CustomerID')
df_customer_att.rename(columns = {'Quantity':'Total Items','Ordercount': 'Total Orders','Total Price':'Total Sales'}, inplace = True)
df_customer_att['Average Basket'] = round(df_customer_att['Total Sales']/ df_customer_att['Total Orders'])
df_customer_att.head(5)

# %% [markdown]
# ### Cleaning the Data

# %% [markdown]
# #### Removing customers with negative sales

# %%
## Removing customers with negative sales

print (df_customer_att.shape)
print (df_customer_rfm.shape)

df_customer_att = df_customer_att[df_customer_att['Total Sales'] > 0]
df_customer_rfm = df_customer_rfm[df_customer_rfm['Monetory'] > 0 ]

print (df_customer_att.shape)
print (df_customer_rfm.shape)

# %%
for col in ['Total Sales','Total Items','Total Orders','Average Basket']:
    print (col)

# %% [markdown]
# #### Removing the outliers

# %%
## Removing the outliers



print (df_customer_att.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
print (df_customer_rfm.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')


for col in ['Total Sales','Total Items','Total Orders','Average Basket']:

    mn = df_customer_att[col].mean()
    sd = df_customer_att[col].std()
    ## Checking if the that column has outliers
    def isnotoutlier(n):
        if n > (mn+ (3* sd)):
            return False
        elif n < (mn - (3* sd)):
            return False
        else:
            return True

    is_notoutlier = df_customer_att[col].map(isnotoutlier)

    df_customer_att = df_customer_att[is_notoutlier]
    df_customer_rfm = df_customer_rfm[is_notoutlier]


print (df_customer_att.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
print (df_customer_rfm.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

# %%
print (df_customer_att.shape,df_customer_rfm.shape)
print(df_customer_att.head(5))

# %% [markdown]
# ## CLUSTERING

# %% [markdown]
# #### Over all customer attributes

# %%
## Clustering Based on Customer attributes

from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

# creating dataframe without customerid for clustering
df_temp = df_customer_att.drop(columns=['CustomerID', 'ActiveMonths'])

# getting the z-values and storing the mean and standard deviations to unscale them whenever needed

means = []
stds = []
i = 0
df_scaled = pd.DataFrame()
for var in df_temp.columns:
    means.append(df_temp[var].mean())
    stds.append(df_temp[var].std())
    df_scaled[var] = (df_temp[var] - means[i])/stds[i]
    i = i+ 1

print (df_scaled.head(5))

# Clustering
data = df_scaled.values[:,:]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1,n_init = 50)
    kmeans.fit(data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# %%
## clustering

kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(data)
cluster_centers = kmeans.cluster_centers_
print (cluster_centers)

df_temp['OverallCluster'] = kmeans.predict(df_scaled)
df_customer_att['OverallCluster'] = kmeans.predict(df_scaled)
print (df_temp['OverallCluster'].value_counts())

# %%
## Unscaling the cluster coefficients
import copy
m = 0
n = 0
cluster_centers_org = copy.deepcopy(cluster_centers)


for m in range(len(cluster_centers)):
    for n in range(len(cluster_centers[m])):
        cluster_centers_org[m][n] = (cluster_centers[m][n]*stds[n])+means[n]

# for x in range(len(cluster_centers_org)):
#     print (cluster_centers_org[x])

# %%
df_scaled.head(5)

# %%
scatter(df_customer_att['Total Sales'],df_customer_att['Recency'], c=df_customer_att['OverallCluster'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# #### Clustering based on RFM Segments

# %%
## Clusters Based on RFM segments

df_rfm_temp = df_customer_rfm.drop(columns=['CustomerID'])

# #Scaling the columns

# means = []
# stds = []
# i = 0
# df_scaled = pd.DataFrame()
# for var in df_temp.columns:
#     means.append(df_temp[var].mean())
#     stds.append(df_temp[var].std())
#     df_scaled[var] = (df_temp[var] - means[i])/stds[i]
#     i = i+ 1


df_rfm_scaled = df_rfm_temp.apply(lambda x: (x - np.mean(x)) / np.std(x), axis=0)


rfm_data = df_rfm_scaled.values[:,:]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(rfm_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(rfm_data)
rfm_cluster_centers = kmeans.cluster_centers_
print (rfm_cluster_centers)
df_customer_rfm['RFMCluster'] = kmeans.predict(rfm_data)

print (df_customer_rfm['RFMCluster'].value_counts())

# %%
df_rfm_temp.head(5)

# %%
scatter(df_customer_rfm['Monetory'], df_customer_rfm["Recency"], c=df_customer_rfm['RFMCluster'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# #### Based on Monetory Value

# %%
#Clusters on Monetory value

monetory_data = df_customer_rfm[['Monetory']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(monetory_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(monetory_data)
monetory_cluster_centers = kmeans.cluster_centers_
print (monetory_cluster_centers)
df_customer_rfm['MonetoryCluster'] = kmeans.predict(monetory_data)

print (df_customer_rfm['MonetoryCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(4)


df_customer_rfm['MonetoryCluster'] = lut[kmeans.labels_]
df_customer_rfm['MonetoryCluster'] = df_customer_rfm['MonetoryCluster'].apply(lambda x:x+1)
print (df_customer_rfm['MonetoryCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['MonetoryCluster'],df_customer_rfm['Monetory'])

# %% [markdown]
# #### Based on Frequency

# %%
#Clusters on Frequency value

frequency_data = df_customer_rfm[['Frequency']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(frequency_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(frequency_data)
frequency_cluster_centers = kmeans.cluster_centers_
print (frequency_cluster_centers)
df_customer_rfm['FrequencyCluster'] = kmeans.predict(frequency_data)
print (df_customer_rfm['FrequencyCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(4)

df_customer_rfm['FrequencyCluster'] = lut[kmeans.labels_]
df_customer_rfm['FrequencyCluster'] = df_customer_rfm['FrequencyCluster'].apply(lambda x:x+1)
print (df_customer_rfm['FrequencyCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['FrequencyCluster'],df_customer_rfm['Frequency'])

# %% [markdown]
# #### Based on Recency

# %%
#Clusters on Recency value

recency_data = df_customer_rfm[['Recency']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(recency_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(recency_data)
recency_cluster_centers = kmeans.cluster_centers_
print (recency_cluster_centers)
df_customer_rfm['RecencyCluster'] = kmeans.predict(recency_data)

print(df_customer_rfm['RecencyCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(3,-1,-1)


df_customer_rfm['RecencyCluster'] = lut[kmeans.labels_]
df_customer_rfm['RecencyCluster'] = df_customer_rfm['RecencyCluster'].apply(lambda x:x+1)
print(df_customer_rfm['RecencyCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['RecencyCluster'],df_customer_rfm['Recency'])

# %% [markdown]
# ### Getting the RFM segments together

# %%
df_customer_rfm['RFMCombined'] = (df_customer_rfm['RecencyCluster']*100)+((df_customer_rfm['FrequencyCluster']*10))+df_customer_rfm['MonetoryCluster']
print (df_customer_rfm.head(5))
df_customer_rfm = df_customer_rfm.drop(columns=['RFMCluster','RecencyCluster','FrequencyCluster','MonetoryCluster'])
print(df_customer_rfm.head(5))

# %%
scatter(df_customer_rfm['Monetory'], df_customer_rfm["Recency"], c=df_customer_rfm['RFMCombined'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# ## Market Basket

# %%
import pandas as pd

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
filename = 'Retail Transactions Data.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
df_apriori = pd.read_csv(filename,parse_dates=['InvoiceDate'], date_parser=dateparse,encoding='cp1252')

# %%
print(df_apriori.shape)
print(df_apriori.head(5))
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
## Cleaning the data - Removing nulls and returns 

df_apriori.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df_apriori['InvoiceNo'] = df_apriori['InvoiceNo'].astype('str')
df_apriori = df_apriori[~df_apriori['InvoiceNo'].str.contains('C')]

# %%
## Cleaning the description - removing spaces, nulls, bad entries

print('Initial shape:', df_apriori.shape)
df_apriori.dropna(axis = 0,subset = ['Description'],inplace = True)
print('Removed Nulls:', df_apriori.shape)

df_apriori = df_apriori[df_apriori['Description'].str.len() > 10]
print('Removed bad entries:', df_apriori.shape)

df_apriori['Description'] = df_apriori['Description'].str.strip()
print('Stripped the spaces:', df_apriori.shape)


def check(s):
    cnt = 0
    for word in ['?','damage','Damage','wrong','Wrong','thrown','Thrown','postage','Postage']:
        if  word in s:
            cnt = 1
    if cnt == 1:
        return False
    else:
        return True

df_apriori = df_apriori[df_apriori['Description'].map(check)]
print('Furthur Removed bad entries:', df_apriori.shape)
# Out:
# Initial shape: (532621, 8)
# Removed Nulls: (531167, 8)
# Removed bad entries: (528189, 8)
# Stripped the spaces: (528189, 8)
# Furthur Removed bad entries: (528126, 8)

# %%
basket = (df_apriori
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket.head(1)
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
#
# Description  ...  sold as set by dotcom  sold as set on dotcom  \
# InvoiceNo    ...
# 536365       ...                    0.0                    0.0
#
# Description  sold as set on dotcom and amazon  sold as set/6 by dotcom  \
# InvoiceNo
# 536365                                    0.0                      0.0
#
# Description  stock check  taig adjust  taig adjust no stock  temp adjustment  \
# InvoiceNo
# 536365               0.0          0.0                   0.0              0.0
#
# Description  to push order througha s stock was  website fixed
# InvoiceNo
# 536365                                      0.0            0.0
#
# [1 rows x 4066 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# %%
## Getting itemsets with support > 5%

frequent_itemsets = apriori(basket_sets, min_support=0.02, use_colnames=True)

# %%
frequent_itemsets.shape
# Out:
# (381, 2)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.sort_values(by=['lift'],ascending = False).head(30)
# Out:
#                                            antecedents  \
# 162                   (PINK REGENCY TEACUP AND SAUCER)
# 159  (ROSES REGENCY TEACUP AND SAUCER, GREEN REGENC...
# 158  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 163                  (GREEN REGENCY TEACUP AND SAUCER)
# 24                    (PINK REGENCY TEACUP AND SAUCER)
# 25                   (GREEN REGENCY TEACUP AND SAUCER)
# 160  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 161                  (ROSES REGENCY TEACUP AND SAUCER)
# 22                 (GARDENERS KNEELING PAD CUP OF TEA)
# 23                  (GARDENERS KNEELING PAD KEEP CALM)
# 169                  (GREEN REGENCY TEACUP AND SAUCER)
# 164  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 168                  (ROSES REGENCY TEACUP AND SAUCER)
# 165  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...
# 141                   (PINK REGENCY TEACUP AND SAUCER)
# 140                  (ROSES REGENCY TEACUP AND SAUCER)
# 29                   (GREEN REGENCY TEACUP AND SAUCER)
# 28                   (ROSES REGENCY TEACUP AND SAUCER)
# 18                              (DOLLY GIRL LUNCH BOX)
# 19                                (SPACEBOY LUNCH BOX)
# 44                                  (JUMBO BAG APPLES)
# 45                                   (JUMBO BAG PEARS)
# 10                       (CHARLOTTE BAG PINK POLKADOT)
# 11                       (RED RETROSPOT CHARLOTTE BAG)
# 152                         (STRAWBERRY CHARLOTTE BAG)
# 153                           (WOODLAND CHARLOTTE BAG)
# 14                          (STRAWBERRY CHARLOTTE BAG)
# 15                         (CHARLOTTE BAG SUKI DESIGN)
# 144                         (STRAWBERRY CHARLOTTE BAG)
# 145                      (RED RETROSPOT CHARLOTTE BAG)
#
#                                            consequents  antecedent support  \
# 162  (ROSES REGENCY TEACUP AND SAUCER, GREEN REGENC...            0.038502
# 159                   (PINK REGENCY TEACUP AND SAUCER)            0.038603
# 158                  (GREEN REGENCY TEACUP AND SAUCER)            0.030108
# 163  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.051018
# 24                   (GREEN REGENCY TEACUP AND SAUCER)            0.038502
# 25                    (PINK REGENCY TEACUP AND SAUCER)            0.051018
# 160                  (ROSES REGENCY TEACUP AND SAUCER)            0.031817
# 161  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...            0.053581
# 22                  (GARDENERS KNEELING PAD KEEP CALM)            0.038100
# 23                 (GARDENERS KNEELING PAD CUP OF TEA)            0.045891
# 169  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...            0.051018
# 164                  (GREEN REGENCY TEACUP AND SAUCER)            0.026389
# 168  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...            0.053581
# 165                  (ROSES REGENCY TEACUP AND SAUCER)            0.025584
# 141                  (ROSES REGENCY TEACUP AND SAUCER)            0.038502
# 140                   (PINK REGENCY TEACUP AND SAUCER)            0.053581
# 29                   (ROSES REGENCY TEACUP AND SAUCER)            0.051018
# 28                   (GREEN REGENCY TEACUP AND SAUCER)            0.053581
# 18                                (SPACEBOY LUNCH BOX)            0.042724
# 19                              (DOLLY GIRL LUNCH BOX)            0.045237
# 44                                   (JUMBO BAG PEARS)            0.049158
# 45                                  (JUMBO BAG APPLES)            0.029907
# 10                       (RED RETROSPOT CHARLOTTE BAG)            0.037346
# 11                       (CHARLOTTE BAG PINK POLKADOT)            0.051973
# 152                           (WOODLAND CHARLOTTE BAG)            0.036291
# 153                         (STRAWBERRY CHARLOTTE BAG)            0.041970
# 14                         (CHARLOTTE BAG SUKI DESIGN)            0.036291
# 15                          (STRAWBERRY CHARLOTTE BAG)            0.044333
# 144                      (RED RETROSPOT CHARLOTTE BAG)            0.036291
# 145                         (STRAWBERRY CHARLOTTE BAG)            0.051973
#
#      consequent support   support  confidence       lift  leverage  conviction
# 162            0.038603  0.027243    0.707572  18.329611  0.025757    3.287636
# 159            0.038502  0.027243    0.705729  18.329611  0.025757    3.267391
# 158            0.051018  0.027243    0.904841  17.735783  0.025707    9.972637
# 163            0.030108  0.027243    0.533990  17.735783  0.025707    2.081269
# 24             0.051018  0.031817    0.826371  16.197681  0.029853    5.465566
# 25             0.038502  0.031817    0.623645  16.197681  0.029853    2.554765
# 160            0.053581  0.027243    0.856240  15.980204  0.025538    6.583330
# 161            0.031817  0.027243    0.508443  15.980204  0.025538    1.969624
# 22             0.045891  0.027444    0.720317  15.696275  0.025696    3.411390
# 23             0.038100  0.027444    0.598028  15.696275  0.025696    2.392956
# 169            0.026389  0.020508    0.401970  15.232766  0.019161    1.628032
# 164            0.051018  0.020508    0.777143  15.232766  0.019161    4.258253
# 168            0.025584  0.020508    0.382739  14.959915  0.019137    1.578613
# 165            0.053581  0.020508    0.801572  14.959915  0.019137    4.769575
# 141            0.053581  0.030108    0.781984  14.594351  0.028045    4.341058
# 140            0.038502  0.030108    0.561914  14.594351  0.028045    2.194768
# 29             0.053581  0.038603    0.756650  14.121535  0.035869    3.889129
# 28             0.051018  0.038603    0.720450  14.121535  0.035869    3.394681
# 18             0.045237  0.027042    0.632941  13.991516  0.025109    2.601116
# 19             0.042724  0.027042    0.597778  13.991516  0.025109    2.379967
# 44             0.029907  0.020407    0.415133  13.880789  0.018937    1.658655
# 45             0.049158  0.020407    0.682353  13.880789  0.018937    2.993391
# 10             0.051973  0.026238    0.702557  13.517771  0.024297    3.187259
# 11             0.037346  0.026238    0.504836  13.517771  0.024297    1.944110
# 152            0.041970  0.020407    0.562327  13.398195  0.018884    2.188916
# 153            0.036291  0.020407    0.486228  13.398195  0.018884    1.875752
# 14             0.044333  0.020860    0.574792  12.965410  0.019251    2.247530
# 15             0.036291  0.020860    0.470522  12.965410  0.019251    1.820111
# 144            0.051973  0.024428    0.673130  12.951572  0.022542    2.900320
# 145            0.036291  0.024428    0.470019  12.951572  0.022542    1.818386

# %%
## Blue green ivory pink black 
## for each two products, check if all words except two are similar, then remove the unsimilar word and attach the remaining together

# %%
df_products = pd.DataFrame(df_apriori['Description'].value_counts()).reset_index()
print(df_products.head(5))
print(df_products.shape)
# Out:
#                                 index  Description
# 0  WHITE HANGING HEART T-LIGHT HOLDER         2327
# 1             JUMBO BAG RED RETROSPOT         2115
# 2            REGENCY CAKESTAND 3 TIER         2019
# 3                       PARTY BUNTING         1707
# 4             LUNCH BAG RED RETROSPOT         1594
# (4066, 2)

# %%
## Jugaaaad

def jugaad(s):
    s = s.strip()
    new_word = ''
    words_s = s.split(' ')
    for product in df_products['index'].value_counts().index.to_list():
        product = product.strip()
        words_p = product.split(' ')
        similar_words = [i for i, j in zip(words_s, words_p) if i == j]
        if len(similar_words) == (len(words_s)-1):
            new_word = ' '.join(similar_words)
            return product
    return s
#     if len(new_word) > 2:
#         return new_word
#     else:
#         return s
            

def prolevel(s):
    s = s.strip()
    new_word = ''
    words_s = s.split(' ')
    for product in df_products['index'].value_counts().index.to_list():
        product = product.strip()
        words_p = product.split(' ')
        similar_words = [i for i, j in zip(words_s, words_p) if i == j]
        if len(similar_words) == (len(words_s)-1):
            new_word = ' '.join(similar_words)
            return new_word
    return s
#     if len(new_word) > 2:
#         return new_word
#     else:
#         return s

    

df_products['Similar Products'] = df_products['index'].map(jugaad)
print(df_products.shape)
df_products['New Description'] = df_products['index'].map(prolevel)
# Out:
# (4066, 3)

# %%
df_products.head(5)
df_products = df_products.drop(columns=['Description'])
df_products.rename(columns = {'index':'Description'}, inplace = True) 
df_products.head(5)
# Out:
#                           Description                    Similar Products  \
# 0  WHITE HANGING HEART T-LIGHT HOLDER  CREAM HANGING HEART T-LIGHT HOLDER
# 1             JUMBO BAG RED RETROSPOT             LUNCH BAG RED RETROSPOT
# 2            REGENCY CAKESTAND 3 TIER         SWEETHEART CAKESTAND 3 TIER
# 3                       PARTY BUNTING       PAPER BUNTING VINTAGE PAISLEY
# 4             LUNCH BAG RED RETROSPOT             JUMBO BAG RED RETROSPOT
#
#                 New Description
# 0  HANGING HEART T-LIGHT HOLDER
# 1             BAG RED RETROSPOT
# 2              CAKESTAND 3 TIER
# 3                       BUNTING
# 4             BAG RED RETROSPOT

# %%
df_apriori.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df_apriori_new = df_apriori.merge(df_products, on = ['Description'] )
print(df_apriori_new.head(5))
df_apriori_new = df_apriori_new.drop(columns=['Description','Similar Products'])
print(df_apriori_new.head(5))
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 2    536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 3    536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 4    536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 09:02:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 09:32:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 10:19:00       2.55     17511.0  United Kingdom
# 4 2010-12-01 10:39:00       2.55     13408.0  United Kingdom
#
#                      Similar Products               New Description
# 0  CREAM HANGING HEART T-LIGHT HOLDER  HANGING HEART T-LIGHT HOLDER
# 1  CREAM HANGING HEART T-LIGHT HOLDER  HANGING HEART T-LIGHT HOLDER
# 2  CREAM HANGING HEART T-LIGHT HOLDER  HANGING HEART T-LIGHT HOLDER
# 3  CREAM HANGING HEART T-LIGHT HOLDER  HANGING HEART T-LIGHT HOLDER
# 4  CREAM HANGING HEART T-LIGHT HOLDER  HANGING HEART T-LIGHT HOLDER
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536373    85123A         6 2010-12-01 09:02:00       2.55     17850.0
# 2    536375    85123A         6 2010-12-01 09:32:00       2.55     17850.0
# 3    536390    85123A        64 2010-12-01 10:19:00       2.55     17511.0
# 4    536394    85123A        32 2010-12-01 10:39:00       2.55     13408.0
#
#           Country               New Description
# 0  United Kingdom  HANGING HEART T-LIGHT HOLDER
# 1  United Kingdom  HANGING HEART T-LIGHT HOLDER
# 2  United Kingdom  HANGING HEART T-LIGHT HOLDER
# 3  United Kingdom  HANGING HEART T-LIGHT HOLDER
# 4  United Kingdom  HANGING HEART T-LIGHT HOLDER

# %%
basket_new = (df_apriori_new
          .groupby(['InvoiceNo', 'New Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_new.head(1)
# Out:
# New Description        DESIGN  COTTON TOTE BAG   DIAMANTE PEN IN GIFT BOX  \
# InvoiceNo
# 536365           0.0                       0.0                        0.0
#
# New Description   IMAGES NOTEBOOK SET   STICKERS   WRITING SET  \
# InvoiceNo
# 536365                            0.0        0.0           0.0
#
# New Description  & WHITE BREAKFAST TRAY  *Boombox Ipod Classic  \
# InvoiceNo
# 536365                              0.0                    0.0
#
# New Description  *USB Office Mirror Ball  1 WICK MORRIS BOXED CANDLE  ...  \
# InvoiceNo                                                             ...
# 536365                               0.0                         0.0  ...
#
# New Description  sold as by dotcom  sold as set dotcom  \
# InvoiceNo
# 536365                         0.0                 0.0
#
# New Description  sold as set on dotcom and amazon  sold sets  stock check  \
# InvoiceNo
# 536365                                        0.0        0.0          0.0
#
# New Description  stock entry.  taig adjust no stock  temp adjustment  \
# InvoiceNo
# 536365                    0.0                   0.0              0.0
#
# New Description  to push order througha s stock was  website fixed
# InvoiceNo
# 536365                                          0.0            0.0
#
# [1 rows x 2925 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets_new = basket_new.applymap(encode_units)

# %%
## Getting itemsets with support > 5%

frequent_itemsets = apriori(basket_sets_new, min_support=0.02, use_colnames=True)
print(frequent_itemsets.shape)
# Out:
# (573, 2)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules.sort_values(by=['lift'],ascending = False).head(50)
# Out:
#                                            antecedents  \
# 232                (GARDENERS KNEELING PAD CUP OF TEA)
# 233                 (GARDENERS KNEELING PAD KEEP CALM)
# 234                               (HAND WARMER DESIGN)
# 235                    (HAND WARMER SCOTTY DOG DESIGN)
# 221                             (DOLLY GIRL LUNCH BOX)
# 220                                        (LUNCH BOX)
# 219                                    (CHARLOTTE BAG)
# 218                                     (WOODLAND BAG)
# 389               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 388                           (SET/6 RED SPOTTY PAPER)
# 171                                    (CHARLOTTE BAG)
# 170                                  (BAG SUKI DESIGN)
# 176                                  (BAG SUKI DESIGN)
# 177                                     (WOODLAND BAG)
# 377                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 376                                  (PLASTERS IN TIN)
# 375                    (PLASTERS IN TIN CIRCUS PARADE)
# 374                                  (PLASTERS IN TIN)
# 866     (JUMBO BAG, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 867             (BAG RED RETROSPOT, JUMBO STORAGE BAG)
# 529                                    (CHARLOTTE BAG)
# 524             (RED RETROSPOT BAG, BAG PINK POLKADOT)
# 587                       (JUMBO BAG WOODLAND ANIMALS)
# 586             (BAG PINK POLKADOT, JUMBO STORAGE BAG)
# 258                                 (HOT WATER BOTTLE)
# 259                  (HOT WATER BOTTLE I AM SO POORLY)
# 803                       (JUMBO BAG WOODLAND ANIMALS)
# 802                     (JUMBO BAG, JUMBO STORAGE BAG)
# 390                (WOODEN PICTURE FRAME WHITE FINISH)
# 391                       (WOODEN FRAME ANTIQUE WHITE)
# 865                     (JUMBO BAG, JUMBO STORAGE BAG)
# 868  (BAG RED RETROSPOT, JUMBO SHOPPER VINTAGE RED ...
# 584    (JUMBO BAG WOODLAND ANIMALS, BAG PINK POLKADOT)
# 589                                (JUMBO STORAGE BAG)
# 522                                  (BAG SUKI DESIGN)
# 519             (RED RETROSPOT BAG, BAG PINK POLKADOT)
# 637                                     (WOODLAND BAG)
# 632             (RED RETROSPOT BAG, BAG PINK POLKADOT)
# 882             (BAG RED RETROSPOT, JUMBO STORAGE BAG)
# 879                     (JUMBO BAG, RED RETROSPOT BAG)
# 262                                 (HOT WATER BOTTLE)
# 263                (HOT WATER BOTTLE TEA AND SYMPATHY)
# 736             (BAG RED RETROSPOT, JUMBO STORAGE BAG)
# 737                       (JUMBO BAG WOODLAND ANIMALS)
# 0                        (60 TEATIME FAIRY CAKE CASES)
# 1                              (PACK OF 60 CAKE CASES)
# 837                     (JUMBO BAG, BAG PINK POLKADOT)
# 840             (BAG RED RETROSPOT, JUMBO STORAGE BAG)
# 872                                (JUMBO STORAGE BAG)
# 861  (JUMBO BAG, BAG RED RETROSPOT, JUMBO SHOPPER V...
#
#                                            consequents  antecedent support  \
# 232                 (GARDENERS KNEELING PAD KEEP CALM)            0.038100
# 233                (GARDENERS KNEELING PAD CUP OF TEA)            0.045891
# 234                    (HAND WARMER SCOTTY DOG DESIGN)            0.055441
# 235                               (HAND WARMER DESIGN)            0.027545
# 221                                        (LUNCH BOX)            0.042724
# 220                             (DOLLY GIRL LUNCH BOX)            0.045237
# 219                                     (WOODLAND BAG)            0.036291
# 218                                    (CHARLOTTE BAG)            0.041970
# 389                           (SET/6 RED SPOTTY PAPER)            0.049560
# 388               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.030410
# 171                                  (BAG SUKI DESIGN)            0.036291
# 170                                    (CHARLOTTE BAG)            0.044333
# 176                                     (WOODLAND BAG)            0.044333
# 177                                  (BAG SUKI DESIGN)            0.041970
# 377                                  (PLASTERS IN TIN)            0.035386
# 376                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.062930
# 375                                  (PLASTERS IN TIN)            0.028701
# 374                    (PLASTERS IN TIN CIRCUS PARADE)            0.062930
# 866             (BAG RED RETROSPOT, JUMBO STORAGE BAG)            0.037044
# 867     (JUMBO BAG, JUMBO SHOPPER VINTAGE RED PAISLEY)            0.050666
# 529             (RED RETROSPOT BAG, BAG PINK POLKADOT)            0.036291
# 524                                    (CHARLOTTE BAG)            0.051923
# 587             (BAG PINK POLKADOT, JUMBO STORAGE BAG)            0.043378
# 586                       (JUMBO BAG WOODLAND ANIMALS)            0.043629
# 258                  (HOT WATER BOTTLE I AM SO POORLY)            0.066801
# 259                                 (HOT WATER BOTTLE)            0.033023
# 803                     (JUMBO BAG, JUMBO STORAGE BAG)            0.043378
# 802                       (JUMBO BAG WOODLAND ANIMALS)            0.052526
# 390                       (WOODEN FRAME ANTIQUE WHITE)            0.055290
# 391                (WOODEN PICTURE FRAME WHITE FINISH)            0.048806
# 865  (BAG RED RETROSPOT, JUMBO SHOPPER VINTAGE RED ...            0.052526
# 868                     (JUMBO BAG, JUMBO STORAGE BAG)            0.038603
# 584                                (JUMBO STORAGE BAG)            0.027092
# 589    (JUMBO BAG WOODLAND ANIMALS, BAG PINK POLKADOT)            0.076502
# 522             (RED RETROSPOT BAG, BAG PINK POLKADOT)            0.044333
# 519                                  (BAG SUKI DESIGN)            0.051923
# 637             (RED RETROSPOT BAG, BAG PINK POLKADOT)            0.041970
# 632                                     (WOODLAND BAG)            0.051923
# 882                     (JUMBO BAG, RED RETROSPOT BAG)            0.050666
# 879             (BAG RED RETROSPOT, JUMBO STORAGE BAG)            0.044484
# 262                (HOT WATER BOTTLE TEA AND SYMPATHY)            0.066801
# 263                                 (HOT WATER BOTTLE)            0.032320
# 736                       (JUMBO BAG WOODLAND ANIMALS)            0.050666
# 737             (BAG RED RETROSPOT, JUMBO STORAGE BAG)            0.043378
# 0                              (PACK OF 60 CAKE CASES)            0.041618
# 1                        (60 TEATIME FAIRY CAKE CASES)            0.053682
# 837             (BAG RED RETROSPOT, JUMBO STORAGE BAG)            0.060216
# 840                     (JUMBO BAG, BAG PINK POLKADOT)            0.050666
# 872  (JUMBO BAG, BAG RED RETROSPOT, JUMBO SHOPPER V...            0.076502
# 861                                (JUMBO STORAGE BAG)            0.028801
#
#      consequent support   support  confidence       lift  leverage  conviction
# 232            0.045891  0.027444    0.720317  15.696275  0.025696    3.411390
# 233            0.038100  0.027444    0.598028  15.696275  0.025696    2.392956
# 234            0.027545  0.021865    0.394379  14.317828  0.020338    1.605716
# 235            0.055441  0.021865    0.793796  14.317828  0.020338    4.580693
# 221            0.045237  0.027042    0.632941  13.991516  0.025109    2.601116
# 220            0.042724  0.027042    0.597778  13.991516  0.025109    2.379967
# 219            0.041970  0.020407    0.562327  13.398195  0.018884    2.188916
# 218            0.036291  0.020407    0.486228  13.398195  0.018884    1.875752
# 389            0.030410  0.020156    0.406694  13.373837  0.018649    1.634216
# 388            0.049560  0.020156    0.662810  13.373837  0.018649    2.818706
# 171            0.044333  0.020860    0.574792  12.965410  0.019251    2.247530
# 170            0.036291  0.020860    0.470522  12.965410  0.019251    1.820111
# 176            0.041970  0.022920    0.517007  12.318384  0.021060    1.983526
# 177            0.044333  0.022920    0.546108  12.318384  0.021060    2.105494
# 377            0.062930  0.026187    0.740057  11.759928  0.023961    3.604902
# 376            0.035386  0.026187    0.416134  11.759928  0.023961    1.652116
# 375            0.062930  0.020407    0.711033  11.298728  0.018601    3.242829
# 374            0.028701  0.020407    0.324281  11.298728  0.018601    1.437431
# 866            0.050666  0.020307    0.548168  10.819253  0.018430    2.101079
# 867            0.037044  0.020307    0.400794  10.819253  0.018430    1.607052
# 529            0.051923  0.020357    0.560942  10.803425  0.018473    2.159343
# 524            0.036291  0.020357    0.392062  10.803425  0.018473    1.585210
# 587            0.043629  0.020055    0.462341  10.597083  0.018163    1.778768
# 586            0.043378  0.020055    0.459677  10.597083  0.018163    1.770465
# 258            0.033023  0.022518    0.337096  10.207787  0.020312    1.458697
# 259            0.066801  0.022518    0.681887  10.207787  0.020312    2.933550
# 803            0.052526  0.023222    0.535342  10.191986  0.020943    2.039078
# 802            0.043378  0.023222    0.442105  10.191986  0.020943    1.714700
# 390            0.048806  0.027092    0.490000  10.039701  0.024394    1.865086
# 391            0.055290  0.027092    0.555098  10.039701  0.024394    2.123410
# 865            0.038603  0.020307    0.386603  10.014927  0.018279    1.567333
# 868            0.052526  0.020307    0.526042  10.014927  0.018279    1.999067
# 584            0.076502  0.020055    0.740260   9.676391  0.017983    3.555469
# 589            0.027092  0.020055    0.262155   9.676391  0.017983    1.318580
# 522            0.051923  0.022267    0.502268   9.673391  0.019965    1.904793
# 519            0.044333  0.022267    0.428848   9.673391  0.019965    1.673228
# 637            0.051923  0.020960    0.499401   9.618187  0.018781    1.893887
# 632            0.041970  0.020960    0.403679   9.618187  0.018781    1.606566
# 882            0.044484  0.021111    0.416667   9.366761  0.018857    1.638028
# 879            0.050666  0.021111    0.474576   9.366761  0.018857    1.806797
# 262            0.032320  0.020055    0.300226   9.289255  0.017896    1.382846
# 263            0.066801  0.020055    0.620529   9.289255  0.017896    2.459210
# 736            0.043378  0.020357    0.401786   9.262488  0.018159    1.599130
# 737            0.050666  0.020357    0.469293   9.262488  0.018159    1.788811
# 0              0.053682  0.020658    0.496377   9.246645  0.018424    1.879020
# 1              0.041618  0.020658    0.384831   9.246645  0.018424    1.557917
# 837            0.050666  0.028198    0.468280   9.242500  0.025147    1.785404
# 840            0.060216  0.028198    0.556548   9.242500  0.025147    2.119244
# 872            0.028801  0.020307    0.265440   9.216288  0.018103    1.322151
# 861            0.076502  0.020307    0.705061   9.216288  0.018103    3.131151
