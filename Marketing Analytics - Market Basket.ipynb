# %%
import pandas as pd
from pandas import Series,DataFrame
# %pylab inline
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = 'Best RFM First 6 months.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
df_retail = pd.read_csv(filename,parse_dates=['InvoiceDate'])

# %% [markdown]
# #### Removing rows with CustomerID blank

# %%
## Removing rows with CustomerID blank
print (df_retail.shape)

df_retail = df_retail.drop(df_retail[df_retail['CustomerID'].isnull()].index)

print (df_retail.shape)
# Out:
# (34600, 9)
# (34600, 9)

# %% [markdown]
# #### Adding a column "Total  Price" of the transaction

# %%
## adding a column total price of the transaction
df_retail['Total Price'] = df_retail['UnitPrice']* df_retail['Quantity']

# %% [markdown]
# #### Aggregating the details at Invoice level

# %%
## Invoice level details

def dow(dt):
    return dt.day_name()

df_invoice = df_retail.groupby(['InvoiceNo','CustomerID', 'Country','InvoiceDate'])[['Total Price', 'Quantity']].sum()
print (df_invoice.shape)
df_invoice = pd.DataFrame(df_invoice.to_records())
df_invoice['Invoice_Month'] = df_invoice['InvoiceDate'].dt.strftime("%B")
df_invoice['DayofWeek'] = df_invoice['InvoiceDate'].map(dow)
print (df_invoice.shape)
df_invoice.head(5)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Number of Orders by Month

# %%
## Orders by Month

df_monthly = df_invoice.groupby('Invoice_Month')[['InvoiceNo']].count()
df_monthly = pd.DataFrame(df_monthly.to_records())
month_order = ["January", "February", "March", "April", "May", "June", "July","August", "September", "October", "November", "December"]
df_monthly.set_index("Invoice_Month").loc[month_order]['InvoiceNo'].plot(kind = 'bar')
xlabel('Month Name')
ylabel('Number of Orders')
title('Distribution of Orders by Month')

# %% [markdown]
# #### Orders by Day of the Week

# %%
## Orders by Day of the Week

df_dow = df_invoice.groupby('DayofWeek')[['InvoiceNo']].count()
df_dow = pd.DataFrame(df_dow.to_records())
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df_dow.set_index("DayofWeek").loc[day_order]['InvoiceNo'].plot(kind = 'bar')
xlabel('Day of the Week')
ylabel('Number of Orders')
title('Distribution of Orders by Day of the Week')

# %% [markdown]
# #### Orders by Country

# %%
## Orders by Country

df_country = df_invoice.groupby('Country')[['InvoiceNo']].count()
df_country = pd.DataFrame(df_country.to_records())
df_country.set_index("Country")['InvoiceNo'].plot(kind = 'bar')
xlabel('Country')
ylabel('Number of Orders')
title('Distribution of Orders by Country')

# %% [markdown]
# #### Aggregating Data at Customer Level for every month

# %%
## Getting data at a customer level
## customer month firstorder of month last order of month total sales in month

## Sales and Quantity by Month
df_customer_sales = df_invoice.groupby(['CustomerID','Invoice_Month'])[['Total Price','Quantity']].sum()
df_customer_sales = pd.DataFrame(df_customer_sales.to_records())
#print (df_customer_sales.head(5))
#print (df_customer_sales.shape)

## Orders by Month
df_customer_orders = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceNo']].count()
df_customer_orders = pd.DataFrame(df_customer_orders.to_records())
#print (df_customer_orders.head(5))
#print (df_customer_orders.shape)

## First order in a Month
df_customer_monthlyfirst = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceDate']].min()
df_customer_monthlyfirst = pd.DataFrame(df_customer_monthlyfirst.to_records())
#print (df_customer_monthlyfirst.head(5))
#print (df_customer_monthlyfirst.shape)

## Last order in a Month
df_customer_monthlylast = df_invoice.groupby(['CustomerID','Invoice_Month'])[['InvoiceDate']].max()
df_customer_monthlylast = pd.DataFrame(df_customer_monthlylast.to_records())
#print (df_customer_monthlylast.head(5))
#print (df_customer_monthlylast.shape)

df_customer = df_customer_sales.merge(df_customer_monthlyfirst, on = ['CustomerID','Invoice_Month'],suffixes = ['_left','_right'])
#print (df_customer.head(5))
df_customer = df_customer.merge(df_customer_monthlylast, on = ['CustomerID','Invoice_Month'],suffixes = ['_firstorder','_lastorder'])
#print (df_customer.head(5))
df_customer = df_customer.merge(df_customer_orders, on = ['CustomerID','Invoice_Month'],suffixes = ['_firstorder','_lastorder'])
#print (df_customer.head(5))




df_customer.rename(columns = {'InvoiceDate_firstorder':'FirstOrder','InvoiceDate_lastorder':'LastOrder','InvoiceNo':'Ordercount'}, inplace = True) 
print (df_customer.head(5))
print (df_customer.shape)

# %% [markdown]
# #### Getting the RFM details of the customer

# %%
from datetime import datetime

def recency(dt):
    dys = (datetime.strptime('2011-12-01', "%Y-%m-%d") - dt).days
    return dys


## RFM for 12 months - December 2010 - November 2011

## monetory value
df_customer_m = df_customer.groupby(['CustomerID'])[['Total Price']].sum()
df_customer_m = pd.DataFrame(df_customer_m.to_records())
df_customer_m.rename(columns = {'Total Price':'Monetory'}, inplace = True) 
#print (df_customer_m.head(5))


## frequency
df_customer_f = df_customer.groupby(['CustomerID'])[['Ordercount']].sum()
df_customer_f = pd.DataFrame(df_customer_f.to_records())
df_customer_f.rename(columns = {'Ordercount':'Frequency'}, inplace = True) 
#print (df_customer_f.head(5))

## recency

df_customer_r = df_customer.groupby(['CustomerID'])[['LastOrder']].max()
df_customer_r = pd.DataFrame(df_customer_r.to_records())
df_customer_r['Recency'] = df_customer_r['LastOrder'].map(recency)
df_customer_r = df_customer_r.drop(columns=['LastOrder'])
#print (df_customer_r.head(5))

## getting RFM together

df_customer_rfm = df_customer_m.merge(df_customer_f,on = ['CustomerID'])
df_customer_rfm = df_customer_rfm.merge(df_customer_r,on = ['CustomerID'])
print (df_customer_rfm.head(5))

# %% [markdown]
# #### Getting all important customer attributes together

# %%
def getdays(s):
    return (s.days+1)

## Getting Aggregated values at customer level

## Total Sales, Orders, Items for the year
df_customer_ov = df_customer.groupby(['CustomerID'])[['Total Price','Quantity','Ordercount']].sum()
df_customer_ov = pd.DataFrame(df_customer_ov.to_records())
#print (df_customer_ov.head(5))

## First Order of Customer
df_customer_first = df_customer.groupby(['CustomerID'])[['FirstOrder']].min()
df_customer_first = pd.DataFrame(df_customer_first.to_records())
#print (df_customer_first.head(5))

## Last Order of Customer
df_customer_last = df_customer.groupby(['CustomerID'])[['LastOrder']].max()
df_customer_last = pd.DataFrame(df_customer_last.to_records())
#print (df_customer_last.head(5))

## Number of active months
df_customer_months = df_customer.groupby(['CustomerID'])[['Invoice_Month']].count()
df_customer_months = pd.DataFrame(df_customer_months.to_records())
df_customer_months.rename(columns = {'Invoice_Month':'ActiveMonths'}, inplace = True) 
#print (df_customer_months.head(5))


## Days between first and last order
df_customer_daysbetween = df_customer_first.merge(df_customer_last, on = 'CustomerID')
df_customer_daysbetween['ActiveDays'] = (df_customer_daysbetween['LastOrder'] - df_customer_daysbetween['FirstOrder']).map(getdays)
#print (df_customer_daysbetween.head(5))

# %%
## Getting all important customer attributes together

df_customer_att = df_customer_ov.merge(df_customer_months, on = 'CustomerID')
df_customer_att = df_customer_att.merge(df_customer_daysbetween, on ='CustomerID')
df_customer_att = df_customer_att.drop(columns=['LastOrder','FirstOrder'])
df_customer_att = df_customer_att.merge(df_customer_r,on = 'CustomerID')
df_customer_att.rename(columns = {'Quantity':'Total Items','Ordercount': 'Total Orders','Total Price':'Total Sales'}, inplace = True)
df_customer_att['Average Basket'] = round(df_customer_att['Total Sales']/ df_customer_att['Total Orders'])
df_customer_att.head(5)

# %% [markdown]
# ### Cleaning the Data

# %% [markdown]
# #### Removing customers with negative sales

# %%
## Removing customers with negative sales

print (df_customer_att.shape)
print (df_customer_rfm.shape)

df_customer_att = df_customer_att[df_customer_att['Total Sales'] > 0]
df_customer_rfm = df_customer_rfm[df_customer_rfm['Monetory'] > 0 ]

print (df_customer_att.shape)
print (df_customer_rfm.shape)

# %%
for col in ['Total Sales','Total Items','Total Orders','Average Basket']:
    print (col)

# %% [markdown]
# #### Removing the outliers

# %%
## Removing the outliers



print (df_customer_att.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
print (df_customer_rfm.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')


for col in ['Total Sales','Total Items','Total Orders','Average Basket']:

    mn = df_customer_att[col].mean()
    sd = df_customer_att[col].std()
    ## Checking if the that column has outliers
    def isnotoutlier(n):
        if n > (mn+ (3* sd)):
            return False
        elif n < (mn - (3* sd)):
            return False
        else:
            return True

    is_notoutlier = df_customer_att[col].map(isnotoutlier)

    df_customer_att = df_customer_att[is_notoutlier]
    df_customer_rfm = df_customer_rfm[is_notoutlier]


print (df_customer_att.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
print (df_customer_rfm.describe())
print ('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

# %%
print (df_customer_att.shape,df_customer_rfm.shape)
print(df_customer_att.head(5))

# %% [markdown]
# ## CLUSTERING

# %% [markdown]
# #### Over all customer attributes

# %%
## Clustering Based on Customer attributes

from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

# creating dataframe without customerid for clustering
df_temp = df_customer_att.drop(columns=['CustomerID', 'ActiveMonths'])

# getting the z-values and storing the mean and standard deviations to unscale them whenever needed

means = []
stds = []
i = 0
df_scaled = pd.DataFrame()
for var in df_temp.columns:
    means.append(df_temp[var].mean())
    stds.append(df_temp[var].std())
    df_scaled[var] = (df_temp[var] - means[i])/stds[i]
    i = i+ 1

print (df_scaled.head(5))

# Clustering
data = df_scaled.values[:,:]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1,n_init = 50)
    kmeans.fit(data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# %%
## clustering

kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(data)
cluster_centers = kmeans.cluster_centers_
print (cluster_centers)

df_temp['OverallCluster'] = kmeans.predict(df_scaled)
df_customer_att['OverallCluster'] = kmeans.predict(df_scaled)
print (df_temp['OverallCluster'].value_counts())

# %%
## Unscaling the cluster coefficients
import copy
m = 0
n = 0
cluster_centers_org = copy.deepcopy(cluster_centers)


for m in range(len(cluster_centers)):
    for n in range(len(cluster_centers[m])):
        cluster_centers_org[m][n] = (cluster_centers[m][n]*stds[n])+means[n]

# for x in range(len(cluster_centers_org)):
#     print (cluster_centers_org[x])

# %%
df_scaled.head(5)

# %%
scatter(df_customer_att['Total Sales'],df_customer_att['Recency'], c=df_customer_att['OverallCluster'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# #### Clustering based on RFM Segments

# %%
## Clusters Based on RFM segments

df_rfm_temp = df_customer_rfm.drop(columns=['CustomerID'])

# #Scaling the columns

# means = []
# stds = []
# i = 0
# df_scaled = pd.DataFrame()
# for var in df_temp.columns:
#     means.append(df_temp[var].mean())
#     stds.append(df_temp[var].std())
#     df_scaled[var] = (df_temp[var] - means[i])/stds[i]
#     i = i+ 1


df_rfm_scaled = df_rfm_temp.apply(lambda x: (x - np.mean(x)) / np.std(x), axis=0)


rfm_data = df_rfm_scaled.values[:,:]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(rfm_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(rfm_data)
rfm_cluster_centers = kmeans.cluster_centers_
print (rfm_cluster_centers)
df_customer_rfm['RFMCluster'] = kmeans.predict(rfm_data)

print (df_customer_rfm['RFMCluster'].value_counts())

# %%
df_rfm_temp.head(5)

# %%
scatter(df_customer_rfm['Monetory'], df_customer_rfm["Recency"], c=df_customer_rfm['RFMCluster'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# #### Based on Monetory Value

# %%
#Clusters on Monetory value

monetory_data = df_customer_rfm[['Monetory']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(monetory_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(monetory_data)
monetory_cluster_centers = kmeans.cluster_centers_
print (monetory_cluster_centers)
df_customer_rfm['MonetoryCluster'] = kmeans.predict(monetory_data)

print (df_customer_rfm['MonetoryCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(4)


df_customer_rfm['MonetoryCluster'] = lut[kmeans.labels_]
df_customer_rfm['MonetoryCluster'] = df_customer_rfm['MonetoryCluster'].apply(lambda x:x+1)
print (df_customer_rfm['MonetoryCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['MonetoryCluster'],df_customer_rfm['Monetory'])

# %% [markdown]
# #### Based on Frequency

# %%
#Clusters on Frequency value

frequency_data = df_customer_rfm[['Frequency']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(frequency_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(frequency_data)
frequency_cluster_centers = kmeans.cluster_centers_
print (frequency_cluster_centers)
df_customer_rfm['FrequencyCluster'] = kmeans.predict(frequency_data)
print (df_customer_rfm['FrequencyCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(4)

df_customer_rfm['FrequencyCluster'] = lut[kmeans.labels_]
df_customer_rfm['FrequencyCluster'] = df_customer_rfm['FrequencyCluster'].apply(lambda x:x+1)
print (df_customer_rfm['FrequencyCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['FrequencyCluster'],df_customer_rfm['Frequency'])

# %% [markdown]
# #### Based on Recency

# %%
#Clusters on Recency value

recency_data = df_customer_rfm[['Recency']]

sum_of_distances = {}
for num_clusters in range(1,10):
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, random_state=1)
    kmeans.fit(recency_data)
    sum_of_distances[num_clusters] = kmeans.inertia_
Series(sum_of_distances).sort_index().plot()
xlabel('Number of clusters')
ylabel('Sum of distances of points to closest cluster centers')

# Clustering
kmeans = KMeans(init='k-means++', n_clusters=4, random_state=1)
kmeans.fit(recency_data)
recency_cluster_centers = kmeans.cluster_centers_
print (recency_cluster_centers)
df_customer_rfm['RecencyCluster'] = kmeans.predict(recency_data)

print(df_customer_rfm['RecencyCluster'].value_counts())

## Sorting the cluster labels
idx = np.argsort(kmeans.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(3,-1,-1)


df_customer_rfm['RecencyCluster'] = lut[kmeans.labels_]
df_customer_rfm['RecencyCluster'] = df_customer_rfm['RecencyCluster'].apply(lambda x:x+1)
print(df_customer_rfm['RecencyCluster'].value_counts())

# %%
plt.scatter(df_customer_rfm['RecencyCluster'],df_customer_rfm['Recency'])

# %% [markdown]
# ### Getting the RFM segments together

# %%
df_customer_rfm['RFMCombined'] = (df_customer_rfm['RecencyCluster']*100)+((df_customer_rfm['FrequencyCluster']*10))+df_customer_rfm['MonetoryCluster']
print (df_customer_rfm.head(5))
df_customer_rfm = df_customer_rfm.drop(columns=['RFMCluster','RecencyCluster','FrequencyCluster','MonetoryCluster'])
print(df_customer_rfm.head(5))

# %%
scatter(df_customer_rfm['Monetory'], df_customer_rfm["Recency"], c=df_customer_rfm['RFMCombined'], cmap='Set3')
plt.xlabel('Total Sales')
plt.ylabel('Recency')

# %% [markdown]
# ## Market Basket

# %%
import pandas as pd

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
filename = 'Best RFM First 6 months.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
df_apriori = pd.read_csv(filename)

# %%
print(df_apriori.shape)
print(df_apriori.head(5))
# Out:
# (34600, 9)
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    536367     84879      ASSORTED COLOUR BIRD ORNAMENT        32
# 1    536367     22745         POPPY'S PLAYHOUSE BEDROOM          6
# 2    536367     22748          POPPY'S PLAYHOUSE KITCHEN         6
# 3    536367     22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 4    536367     22310            IVORY KNITTED MUG COSY          6
#
#    InvoiceDate  UnitPrice  CustomerID         Country  RFM
# 0  40513.35694       1.69       13047  United Kingdom   11
# 1  40513.35694       2.10       13047  United Kingdom   11
# 2  40513.35694       2.10       13047  United Kingdom   11
# 3  40513.35694       3.75       13047  United Kingdom   11
# 4  40513.35694       1.65       13047  United Kingdom   11

# %%
## Cleaning the data - Removing nulls and returns 

df_apriori.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df_apriori['InvoiceNo'] = df_apriori['InvoiceNo'].astype('str')
df_apriori = df_apriori[~df_apriori['InvoiceNo'].str.contains('C')]

# %%
## Cleaning the description - removing spaces, nulls, bad entries

print('Initial shape:', df_apriori.shape)
df_apriori.dropna(axis = 0,subset = ['Description'],inplace = True)
print('Removed Nulls:', df_apriori.shape)

df_apriori = df_apriori[df_apriori['Description'].str.len() > 10]
print('Removed bad entries:', df_apriori.shape)

df_apriori['Description'] = df_apriori['Description'].str.strip()
print('Stripped the spaces:', df_apriori.shape)


def check(s):
    cnt = 0
    for word in ['?','damage','Damage','wrong','Wrong','thrown','Thrown','postage','Postage']:
        if  word in s:
            cnt = 1
    if cnt == 1:
        return False
    else:
        return True

df_apriori = df_apriori[df_apriori['Description'].map(check)]
print('Furthur Removed bad entries:', df_apriori.shape)
# Out:
# Initial shape: (33805, 9)
# Removed Nulls: (33805, 9)
# Removed bad entries: (33596, 9)
# Stripped the spaces: (33596, 9)
# Furthur Removed bad entries: (33596, 9)

# %%
basket = (df_apriori
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket.head(1)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536367                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536367                             0.0                        0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536367                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536367                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536367                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  ...  ZINC METAL HEART DECORATION  \
# InvoiceNo                               ...
# 536367                             0.0  ...                          0.0
#
# Description  ZINC PLANT POT HOLDER  ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536367                         0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536367                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536367                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF  ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536367                                 0.0                               0.0
#
# Description  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536367                                    0.0
#
# [1 rows x 2552 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# %%
## Getting itemsets with support > 5%

frequent_itemsets = apriori(basket_sets, min_support=0.009, use_colnames=True)

# %%
frequent_itemsets.shape
# Out:
# (2223, 2)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
#rules.sort_values(by=['lift'],ascending = False).head(30)

rules[ (rules['lift'] >= 40) & (rules['confidence'] >= 0.7) ].sort_values(by = ['lift'],ascending = False)
# Out:
#                                             antecedents  \
# 1881                       (SET/6 COLLAGE PAPER PLATES)
# 1880                         (SET/6 COLLAGE PAPER CUPS)
# 1461                     (PACK OF 6 SKULL PAPER PLATES)
# 1460                       (PACK OF 6 SKULL PAPER CUPS)
# 4582  (CHILDS GARDEN FORK PINK, CHILDS GARDEN TROWEL...
# 4583  (CHILDS GARDEN TROWEL BLUE, CHILDS GARDEN FORK...
# 4579  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...
# 4578  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...
# 533                  (GARDENERS KNEELING PAD KEEP CALM)
# 532                 (GARDENERS KNEELING PAD CUP OF TEA)
# 4586                          (CHILDS GARDEN FORK BLUE)
# 4575  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...
# 617                               (HAPPY STENCIL CRAFT)
# 616                            (MONSTERS STENCIL CRAFT)
# 2318                          (CHILDS GARDEN FORK BLUE)
# 2315  (CHILDS GARDEN FORK PINK, CHILDS GARDEN TROWEL...
# 2325                          (CHILDS GARDEN FORK BLUE)
# 2320  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...
# 4524  (BLUE SPOT CERAMIC DRAWER KNOB, WHITE SPOT RED...
# 4525  (RED SPOT CERAMIC DRAWER KNOB, WHITE SPOT BLUE...
# 5557           (HERB MARKER PARSLEY, HERB MARKER BASIL)
# 5547  (HERB MARKER MINT, HERB MARKER PARSLEY, HERB M...
# 4680            (HERB MARKER CHIVES, HERB MARKER THYME)
# 4677           (HERB MARKER PARSLEY, HERB MARKER BASIL)
# 5566            (HERB MARKER CHIVES, HERB MARKER THYME)
# 5556  (HERB MARKER MINT, HERB MARKER CHIVES, HERB MA...
# 5559            (HERB MARKER CHIVES, HERB MARKER BASIL)
# 5554  (HERB MARKER MINT, HERB MARKER PARSLEY, HERB M...
# 335                           (CHILDS GARDEN FORK BLUE)
# 334                           (CHILDS GARDEN FORK PINK)
# ...                                                 ...
# 2314  (CHILDS GARDEN FORK PINK, CHILDS GARDEN FORK B...
# 5503  (RED SPOT CERAMIC DRAWER KNOB, WHITE SPOT BLUE...
# 4567  (CHARLOTTE BAG SUKI DESIGN, LUNCH BAG  BLACK S...
# 1774                          (REGENCY TEA PLATE GREEN)
# 1775                          (REGENCY TEA PLATE ROSES)
# 339                           (CHILDS GARDEN FORK BLUE)
# 4540  (BLUE STRIPE CERAMIC DRAWER KNOB, WHITE SPOT R...
# 340                           (CHILDS GARDEN FORK PINK)
# 2322  (CHILDS GARDEN FORK PINK, CHILDS GARDEN FORK B...
# 4234  (SET/10 BLUE POLKADOT PARTY CANDLES, SET/10 RE...
# 219                    (YELLOW COAT RACK PARIS FASHION)
# 5505  (RED STRIPE CERAMIC DRAWER KNOB, WHITE SPOT BL...
# 243                               (BLUE POLKADOT PLATE)
# 2336                          (CHILDS GARDEN FORK PINK)
# 239                                (PINK  POLKADOT CUP)
# 343                           (CHILDS GARDEN FORK PINK)
# 1856               (SET/10 BLUE POLKADOT PARTY CANDLES)
# 1665                   (RECYCLED ACAPULCO MAT LAVENDER)
# 5486  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...
# 5495                       (POPPY'S PLAYHOUSE BATHROOM)
# 5488  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...
# 5493  (POPPY'S PLAYHOUSE LIVINGROOM, POPPY'S PLAYHOU...
# 4546  (BLUE STRIPE CERAMIC DRAWER KNOB, RED STRIPE C...
# 5498  (RED SPOT CERAMIC DRAWER KNOB, RED STRIPE CERA...
# 4509  (BLUE SPOT CERAMIC DRAWER KNOB, BLUE STRIPE CE...
# 1657                       (RECYCLED ACAPULCO MAT BLUE)
# 4170  (POPPY'S PLAYHOUSE LIVINGROOM, POPPY'S PLAYHOU...
# 4171                       (POPPY'S PLAYHOUSE BATHROOM)
# 4972  (JUMBO BAG WOODLAND ANIMALS, LUNCH BAG RED RET...
# 4242  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                                             consequents  antecedent support  \
# 1881                         (SET/6 COLLAGE PAPER CUPS)            0.009340
# 1880                       (SET/6 COLLAGE PAPER PLATES)            0.010674
# 1461                       (PACK OF 6 SKULL PAPER CUPS)            0.010674
# 1460                     (PACK OF 6 SKULL PAPER PLATES)            0.010674
# 4582  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...            0.012675
# 4583  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...            0.012675
# 4579  (CHILDS GARDEN FORK PINK, CHILDS GARDEN TROWEL...            0.011341
# 4578  (CHILDS GARDEN TROWEL BLUE, CHILDS GARDEN FORK...            0.011341
# 533                 (GARDENERS KNEELING PAD CUP OF TEA)            0.011341
# 532                  (GARDENERS KNEELING PAD KEEP CALM)            0.012008
# 4586  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...            0.014009
# 4575                          (CHILDS GARDEN FORK BLUE)            0.010674
# 617                            (MONSTERS STENCIL CRAFT)            0.012675
# 616                               (HAPPY STENCIL CRAFT)            0.011341
# 2318  (CHILDS GARDEN FORK PINK, CHILDS GARDEN TROWEL...            0.014009
# 2315                          (CHILDS GARDEN FORK BLUE)            0.012675
# 2325  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN FORK...            0.014009
# 2320                          (CHILDS GARDEN FORK BLUE)            0.011341
# 4524  (RED SPOT CERAMIC DRAWER KNOB, WHITE SPOT BLUE...            0.011341
# 4525  (BLUE SPOT CERAMIC DRAWER KNOB, WHITE SPOT RED...            0.013342
# 5557  (HERB MARKER MINT, HERB MARKER CHIVES, HERB MA...            0.014676
# 5547            (HERB MARKER CHIVES, HERB MARKER THYME)            0.014676
# 4680           (HERB MARKER PARSLEY, HERB MARKER BASIL)            0.014009
# 4677            (HERB MARKER CHIVES, HERB MARKER THYME)            0.014676
# 5566  (HERB MARKER MINT, HERB MARKER PARSLEY, HERB M...            0.014009
# 5556           (HERB MARKER PARSLEY, HERB MARKER BASIL)            0.014009
# 5559  (HERB MARKER MINT, HERB MARKER PARSLEY, HERB M...            0.014676
# 5554            (HERB MARKER CHIVES, HERB MARKER BASIL)            0.014009
# 335                           (CHILDS GARDEN FORK PINK)            0.014009
# 334                           (CHILDS GARDEN FORK BLUE)            0.014676
# ...                                                 ...                 ...
# 2314                        (CHILDS GARDEN TROWEL BLUE)            0.013342
# 5503  (RED STRIPE CERAMIC DRAWER KNOB, WHITE SPOT RE...            0.013342
# 4567  (RED RETROSPOT CHARLOTTE BAG, LUNCH BAG RED RE...            0.011341
# 1774                          (REGENCY TEA PLATE ROSES)            0.017345
# 1775                          (REGENCY TEA PLATE GREEN)            0.018679
# 339                         (CHILDS GARDEN TROWEL PINK)            0.014009
# 4540  (RED SPOT CERAMIC DRAWER KNOB, RED STRIPE CERA...            0.012008
# 340                         (CHILDS GARDEN TROWEL BLUE)            0.014676
# 2322                        (CHILDS GARDEN TROWEL PINK)            0.013342
# 4234               (SET/10 PINK POLKADOT PARTY CANDLES)            0.012675
# 219                      (BLUE COAT RACK PARIS FASHION)            0.011341
# 5505  (RED SPOT CERAMIC DRAWER KNOB, WHITE SPOT RED ...            0.013342
# 243                               (RED RETROSPOT PLATE)            0.014676
# 2336  (CHILDS GARDEN TROWEL PINK, CHILDS GARDEN TROW...            0.014676
# 239                                 (BLUE POLKADOT CUP)            0.014009
# 343                         (CHILDS GARDEN TROWEL PINK)            0.014676
# 1856               (SET/10 PINK POLKADOT PARTY CANDLES)            0.015344
# 1665                  (RECYCLED ACAPULCO MAT TURQUOISE)            0.011341
# 5486                       (POPPY'S PLAYHOUSE BATHROOM)            0.017345
# 5495  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...            0.018012
# 5488  (POPPY'S PLAYHOUSE LIVINGROOM, POPPY'S PLAYHOU...            0.017345
# 5493  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...            0.018012
# 4546               (WHITE SPOT RED CERAMIC DRAWER KNOB)            0.010674
# 5498               (WHITE SPOT RED CERAMIC DRAWER KNOB)            0.010007
# 4509  (RED SPOT CERAMIC DRAWER KNOB, RED STRIPE CERA...            0.013342
# 1657                      (RECYCLED ACAPULCO MAT GREEN)            0.012008
# 4170                       (POPPY'S PLAYHOUSE BATHROOM)            0.018012
# 4171  (POPPY'S PLAYHOUSE LIVINGROOM, POPPY'S PLAYHOU...            0.018012
# 4972      (JUMBO BAG RED RETROSPOT, LUNCH BAG WOODLAND)            0.012675
# 4242                      (SET/6 RED SPOTTY PAPER CUPS)            0.012008
#
#       consequent support   support  confidence       lift  leverage  \
# 1881            0.010674  0.009340    1.000000  93.687500  0.009240
# 1880            0.009340  0.009340    0.875000  93.687500  0.009240
# 1461            0.010674  0.009340    0.875000  81.976563  0.009226
# 1460            0.010674  0.009340    0.875000  81.976563  0.009226
# 4582            0.011341  0.010674    0.842105  74.253870  0.010530
# 4583            0.011341  0.010674    0.842105  74.253870  0.010530
# 4579            0.012675  0.010674    0.941176  74.253870  0.010530
# 4578            0.012675  0.010674    0.941176  74.253870  0.010530
# 533             0.012008  0.010007    0.882353  73.480392  0.009870
# 532             0.011341  0.010007    0.833333  73.480392  0.009870
# 4586            0.010674  0.010674    0.761905  71.380952  0.010524
# 4575            0.014009  0.010674    1.000000  71.380952  0.010524
# 617             0.011341  0.010007    0.789474  69.613003  0.009863
# 616             0.012675  0.010007    0.882353  69.613003  0.009863
# 2318            0.012675  0.012008    0.857143  67.624060  0.011830
# 2315            0.014009  0.012008    0.947368  67.624060  0.011830
# 2325            0.011341  0.010674    0.761905  67.182073  0.010515
# 2320            0.014009  0.010674    0.941176  67.182073  0.010515
# 4524            0.013342  0.010007    0.882353  66.132353  0.009855
# 4525            0.011341  0.010007    0.750000  66.132353  0.009855
# 5557            0.014009  0.013342    0.909091  64.891775  0.013137
# 5547            0.014009  0.013342    0.909091  64.891775  0.013137
# 4680            0.014676  0.013342    0.952381  64.891775  0.013137
# 4677            0.014009  0.013342    0.909091  64.891775  0.013137
# 5566            0.014676  0.013342    0.952381  64.891775  0.013137
# 5556            0.014676  0.013342    0.952381  64.891775  0.013137
# 5559            0.014009  0.013342    0.909091  64.891775  0.013137
# 5554            0.014676  0.013342    0.952381  64.891775  0.013137
# 335             0.014676  0.013342    0.952381  64.891775  0.013137
# 334             0.014009  0.013342    0.909091  64.891775  0.013137
# ...                  ...       ...         ...        ...       ...
# 2314            0.018679  0.012008    0.900000  48.182143  0.011759
# 5503            0.014676  0.009340    0.700000  47.695455  0.009144
# 4567            0.017345  0.009340    0.823529  47.479638  0.009143
# 1774            0.018679  0.015344    0.884615  47.358516  0.015020
# 1775            0.017345  0.015344    0.821429  47.358516  0.015020
# 339             0.017345  0.011341    0.809524  46.672161  0.011098
# 4540            0.016678  0.009340    0.777778  46.635556  0.009139
# 340             0.018679  0.012675    0.863636  46.235390  0.012401
# 2322            0.017345  0.010674    0.800000  46.123077  0.010442
# 4234            0.020680  0.012008    0.947368  45.809847  0.011746
# 219             0.018012  0.009340    0.823529  45.721133  0.009135
# 5505            0.015344  0.009340    0.700000  45.621739  0.009135
# 243             0.016011  0.010674    0.727273  45.424242  0.010439
# 2336            0.016011  0.010674    0.727273  45.424242  0.010439
# 239             0.016011  0.010007    0.714286  44.613095  0.009782
# 343             0.017345  0.011341    0.772727  44.550699  0.011086
# 1856            0.020680  0.014009    0.913043  44.150070  0.013692
# 1665            0.021348  0.010674    0.941176  44.088235  0.010432
# 5486            0.018012  0.013342    0.769231  42.706553  0.013030
# 5495            0.017345  0.013342    0.740741  42.706553  0.013030
# 5488            0.018012  0.013342    0.769231  42.706553  0.013030
# 5493            0.017345  0.013342    0.740741  42.706553  0.013030
# 4546            0.022015  0.010007    0.937500  42.585227  0.009772
# 5498            0.022015  0.009340    0.933333  42.395960  0.009119
# 4509            0.016678  0.009340    0.700000  41.972000  0.009117
# 1657            0.018679  0.009340    0.777778  41.638889  0.009115
# 4170            0.018012  0.013342    0.740741  41.124829  0.013018
# 4171            0.018012  0.013342    0.740741  41.124829  0.013018
# 4972            0.018012  0.009340    0.736842  40.908382  0.009111
# 4242            0.024683  0.012008    1.000000  40.513514  0.011712
#
#       conviction
# 1881         inf
# 1880    7.925284
# 1461    7.914610
# 1460    7.914610
# 4582    6.261508
# 4583    6.261508
# 4579   16.784523
# 4578   16.784523
# 533     8.397932
# 532     5.931955
# 4586    4.155170
# 4575         inf
# 617     4.696131
# 616     8.392262
# 2318    6.911274
# 2315   18.733823
# 2325    4.152368
# 2320   16.761841
# 4524    8.386591
# 4525    3.954636
# 5557   10.845897
# 5547   10.845897
# 4680   20.691795
# 4677   10.845897
# 5566   20.691795
# 5556   20.691795
# 5559   10.845897
# 5554   20.691795
# 335    20.691795
# 334    10.845897
# ...          ...
# 2314    9.813209
# 5503    3.284412
# 4567    5.568379
# 1774    8.504781
# 1775    5.502869
# 339     5.158939
# 4540    4.424950
# 340     7.196353
# 2322    4.913276
# 4234   18.607071
# 219     5.564599
# 5505    3.282188
# 243     3.607961
# 2336    3.607961
# 239     3.443963
# 343     4.323682
# 1856   11.262175
# 1665   16.637091
# 5486    4.255281
# 5495    3.790241
# 5488    4.255281
# 5493    3.790241
# 4546   15.647765
# 5498   14.669780
# 4509    3.277741
# 1657    4.415944
# 4170    3.787668
# 4171    3.787668
# 4972    3.731554
# 4242         inf
#
# [702 rows x 9 columns]

# %%
rules[ (rules['lift'] >= 40) & (rules['confidence'] >= 0.7) ].to_csv('MarketBasketGood.csv')

# %%
## Blue green ivory pink black 
## for each two products, check if all words except two are similar, then remove the unsimilar word and attach the remaining together

# %%
df_products = pd.DataFrame(df_apriori['Description'].value_counts()).reset_index()
print(df_products.head(5))
print(df_products.shape)
# Out:
#                                 index  Description
# 0  WHITE HANGING HEART T-LIGHT HOLDER          230
# 1            REGENCY CAKESTAND 3 TIER          200
# 2             LUNCH BAG RED RETROSPOT          166
# 3                       PARTY BUNTING          151
# 4       ASSORTED COLOUR BIRD ORNAMENT          134
# (2552, 2)

# %%
## Jugaaaad

def jugaad(s):
    s = s.strip()
    new_word = ''
    words_s = s.split(' ')
    for product in df_products['index'].value_counts().index.to_list():
        product = product.strip()
        words_p = product.split(' ')
        similar_words = [i for i, j in zip(words_s, words_p) if i == j]
        if len(similar_words) == (len(words_s)-1):
            new_word = ' '.join(similar_words)
            return product
    return s
#     if len(new_word) > 2:
#         return new_word
#     else:
#         return s
            

def prolevel(s):
    s = s.strip()
    new_word = ''
    words_s = s.split(' ')
    for product in df_products['index'].value_counts().index.to_list():
        product = product.strip()
        words_p = product.split(' ')
        similar_words = [i for i, j in zip(words_s, words_p) if i == j]
        if len(similar_words) == (len(words_s)-1):
            new_word = ' '.join(similar_words)
            return new_word
    return s
#     if len(new_word) > 2:
#         return new_word
#     else:
#         return s

    

df_products['Similar Products'] = df_products['index'].map(jugaad)
print(df_products.shape)
df_products['New Description'] = df_products['index'].map(prolevel)
# Out:
# (2552, 3)

# %%
df_products.head(5)
df_products = df_products.drop(columns=['Description'])
df_products.rename(columns = {'index':'Description'}, inplace = True) 
df_products.head(5)
# Out:
#                           Description                  Similar Products  \
# 0  WHITE HANGING HEART T-LIGHT HOLDER  RED HANGING HEART T-LIGHT HOLDER
# 1            REGENCY CAKESTAND 3 TIER       SWEETHEART CAKESTAND 3 TIER
# 2             LUNCH BAG RED RETROSPOT           JUMBO BAG RED RETROSPOT
# 3                       PARTY BUNTING    PARTY PIZZA DISH BLUE POLKADOT
# 4       ASSORTED COLOUR BIRD ORNAMENT     ASSORTED COLOUR BIRD ORNAMENT
#
#                  New Description
# 0   HANGING HEART T-LIGHT HOLDER
# 1               CAKESTAND 3 TIER
# 2              BAG RED RETROSPOT
# 3                          PARTY
# 4  ASSORTED COLOUR BIRD ORNAMENT

# %%
df_apriori.head(5)
# Out:
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    536367     84879      ASSORTED COLOUR BIRD ORNAMENT        32
# 1    536367     22745          POPPY'S PLAYHOUSE BEDROOM         6
# 2    536367     22748          POPPY'S PLAYHOUSE KITCHEN         6
# 3    536367     22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 4    536367     22310             IVORY KNITTED MUG COSY         6
#
#    InvoiceDate  UnitPrice  CustomerID         Country  RFM
# 0  40513.35694       1.69       13047  United Kingdom   11
# 1  40513.35694       2.10       13047  United Kingdom   11
# 2  40513.35694       2.10       13047  United Kingdom   11
# 3  40513.35694       3.75       13047  United Kingdom   11
# 4  40513.35694       1.65       13047  United Kingdom   11

# %%
df_apriori_new = df_apriori.merge(df_products, on = ['Description'] )
print(df_apriori_new.head(5))
df_apriori_new = df_apriori_new.drop(columns=['Description','Similar Products'])
print(df_apriori_new.head(5))
# Out:
#   InvoiceNo StockCode                    Description  Quantity  InvoiceDate  \
# 0    536367     84879  ASSORTED COLOUR BIRD ORNAMENT        32  40513.35694
# 1    536536     84879  ASSORTED COLOUR BIRD ORNAMENT        80  40513.57292
# 2    536946     84879  ASSORTED COLOUR BIRD ORNAMENT        16  40515.51944
# 3    537137     84879  ASSORTED COLOUR BIRD ORNAMENT        13  40517.52986
# 4    537204     84879  ASSORTED COLOUR BIRD ORNAMENT         8  40517.61458
#
#    UnitPrice  CustomerID         Country  RFM               Similar Products  \
# 0       1.69       13047  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 1       1.69       18144  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 2       1.69       13013  United Kingdom   10  ASSORTED COLOUR BIRD ORNAMENT
# 3       1.69       16327  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 4       1.69       15555  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
#
#                  New Description
# 0  ASSORTED COLOUR BIRD ORNAMENT
# 1  ASSORTED COLOUR BIRD ORNAMENT
# 2  ASSORTED COLOUR BIRD ORNAMENT
# 3  ASSORTED COLOUR BIRD ORNAMENT
# 4  ASSORTED COLOUR BIRD ORNAMENT
#   InvoiceNo StockCode  Quantity  InvoiceDate  UnitPrice  CustomerID  \
# 0    536367     84879        32  40513.35694       1.69       13047
# 1    536536     84879        80  40513.57292       1.69       18144
# 2    536946     84879        16  40515.51944       1.69       13013
# 3    537137     84879        13  40517.52986       1.69       16327
# 4    537204     84879         8  40517.61458       1.69       15555
#
#           Country  RFM                New Description
# 0  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 1  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 2  United Kingdom   10  ASSORTED COLOUR BIRD ORNAMENT
# 3  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT
# 4  United Kingdom   11  ASSORTED COLOUR BIRD ORNAMENT

# %%
basket_new = (df_apriori_new
          .groupby(['InvoiceNo', 'New Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_new.head(1)
# Out:
# New Description   DESIGN  COTTON TOTE BAG   STICKERS   WRITING SET  \
# InvoiceNo
# 536367                                0.0        0.0           0.0
#
# New Description  & WHITE BREAKFAST TRAY  1 WICK MORRIS BOXED CANDLE  \
# InvoiceNo
# 536367                              0.0                         0.0
#
# New Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536367                              0.0                         0.0
#
# New Description  12 DAISY PEGS IN WOOD BOX  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536367                                 0.0                              0.0
#
# New Description  12 PENCIL SMALL TUBE WOODLAND  ...  \
# InvoiceNo                                       ...
# 536367                                     0.0  ...
#
# New Description  ZINC HEART T-LIGHT HOLDER  ZINC HEART WALL ORGANISER  \
# InvoiceNo
# 536367                                 0.0                        0.0
#
# New Description  ZINC HEARTS PLANT POT HOLDER  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536367                                    0.0                         0.0
#
# New Description  ZINC METAL HEART DECORATION  ZINC PLANT POT HOLDER  \
# InvoiceNo
# 536367                                   0.0                    0.0
#
# New Description  ZINC T-LIGHT HOLDER LARGE  ZINC T-LIGHT HOLDER STARS  \
# InvoiceNo
# 536367                                 0.0                        0.0
#
# New Description  ZINC TOP  2 DOOR WOODEN SHELF  \
# InvoiceNo
# 536367                                     0.0
#
# New Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536367                                        0.0
#
# [1 rows x 1912 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets_new = basket_new.applymap(encode_units)

# %%
## Getting itemsets with support > 5%

frequent_itemsets = apriori(basket_sets_new, min_support=0.02, use_colnames=True)
print(frequent_itemsets.shape)
# Out:
# (480, 2)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules.sort_values(by=['lift'],ascending = False).head(50)
# Out:
#                                            antecedents  \
# 316                   (WHITE SPOT CERAMIC DRAWER KNOB)
# 317                       (STRIPE CERAMIC DRAWER KNOB)
# 321                          (WATERING CAN PINK BUNNY)
# 320                       (WATERING CAN BLUE ELEPHANT)
# 323                (WOOD S/3 CABINET ANT WHITE FINISH)
# 322               (WOOD 2 DRAWER CABINET WHITE FINISH)
# 319                     (TRAVEL CARD WALLET KEEP CALM)
# 318                               (TRAVEL CARD WALLET)
# 312               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 313                       (ROUND SNACK BOXES SET OF 4)
# 179                             (DOLLY GIRL LUNCH BOX)
# 178                                        (LUNCH BOX)
# 173                        (COOK WITH WINE METAL SIGN)
# 172                      (GIN + TONIC DIET METAL SIGN)
# 607                    (PLASTERS IN TIN CIRCUS PARADE)
# 606  (PLASTERS IN TIN, PLASTERS IN TIN WOODLAND ANI...
# 221                     (SCOTTIE DOG HOT WATER BOTTLE)
# 220                           (HEART HOT WATER BOTTLE)
# 174                   (HAND OVER THE CHOCOLATE   SIGN)
# 175                        (COOK WITH WINE METAL SIGN)
# 164                             (CHARLOTTE BAG DESIGN)
# 165                                    (CHARLOTTE BAG)
# 609                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 604   (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TIN)
# 304                    (PLASTERS IN TIN CIRCUS PARADE)
# 305                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 614             (BAG RED RETROSPOT, JUMBO STORAGE BAG)
# 619                     (JUMBO BAG, BAG PINK POLKADOT)
# 608                                  (PLASTERS IN TIN)
# 605  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 599  (WOODEN FRAME ANTIQUE WHITE, HANGING HEART T-L...
# 602                (WOODEN PICTURE FRAME WHITE FINISH)
# 296                    (PLASTERS IN TIN CIRCUS PARADE)
# 297                                  (PLASTERS IN TIN)
# 183                      (GIN + TONIC DIET METAL SIGN)
# 182                   (HAND OVER THE CHOCOLATE   SIGN)
# 616             (BAG PINK POLKADOT, JUMBO STORAGE BAG)
# 617                     (BAG RED RETROSPOT, JUMBO BAG)
# 601                       (WOODEN FRAME ANTIQUE WHITE)
# 600  (WOODEN PICTURE FRAME WHITE FINISH, HANGING HE...
# 452                              (LUNCH BAG CARS BLUE)
# 449                     (LUNCH BAG, BAG PINK POLKADOT)
# 279                                 (LUNCH BAG DESIGN)
# 278                    (LUNCH BAG VINTAGE LEAF DESIGN)
# 568           (BAG RED RETROSPOT, LUNCH BAG CARS BLUE)
# 573                          (LUNCH BAG  BLACK SKULL.)
# 504                     (BAG RED RETROSPOT, JUMBO BAG)
# 505                   (JUMBO  BAG BAROQUE BLACK WHITE)
# 301                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 300                                  (PLASTERS IN TIN)
#
#                                            consequents  antecedent support  \
# 316                       (STRIPE CERAMIC DRAWER KNOB)            0.030687
# 317                   (WHITE SPOT CERAMIC DRAWER KNOB)            0.031354
# 321                       (WATERING CAN BLUE ELEPHANT)            0.032021
# 320                          (WATERING CAN PINK BUNNY)            0.036024
# 323               (WOOD 2 DRAWER CABINET WHITE FINISH)            0.043362
# 322                (WOOD S/3 CABINET ANT WHITE FINISH)            0.031354
# 319                               (TRAVEL CARD WALLET)            0.033356
# 318                     (TRAVEL CARD WALLET KEEP CALM)            0.038692
# 312                       (ROUND SNACK BOXES SET OF 4)            0.044029
# 313               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.046698
# 179                                        (LUNCH BOX)            0.044029
# 178                             (DOLLY GIRL LUNCH BOX)            0.056037
# 173                      (GIN + TONIC DIET METAL SIGN)            0.053369
# 172                        (COOK WITH WINE METAL SIGN)            0.048032
# 607  (PLASTERS IN TIN, PLASTERS IN TIN WOODLAND ANI...            0.046031
# 606                    (PLASTERS IN TIN CIRCUS PARADE)            0.036024
# 221                           (HEART HOT WATER BOTTLE)            0.036024
# 220                     (SCOTTIE DOG HOT WATER BOTTLE)            0.054036
# 174                        (COOK WITH WINE METAL SIGN)            0.042028
# 175                   (HAND OVER THE CHOCOLATE   SIGN)            0.053369
# 164                                    (CHARLOTTE BAG)            0.038025
# 165                             (CHARLOTTE BAG DESIGN)            0.048032
# 609   (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TIN)            0.051368
# 604                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.036024
# 304                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.046031
# 305                    (PLASTERS IN TIN CIRCUS PARADE)            0.051368
# 614                     (JUMBO BAG, BAG PINK POLKADOT)            0.046031
# 619             (BAG RED RETROSPOT, JUMBO STORAGE BAG)            0.040694
# 608  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...            0.076718
# 605                                  (PLASTERS IN TIN)            0.025350
# 599                (WOODEN PICTURE FRAME WHITE FINISH)            0.026017
# 602  (WOODEN FRAME ANTIQUE WHITE, HANGING HEART T-L...            0.075384
# 296                                  (PLASTERS IN TIN)            0.046031
# 297                    (PLASTERS IN TIN CIRCUS PARADE)            0.076718
# 183                   (HAND OVER THE CHOCOLATE   SIGN)            0.048032
# 182                      (GIN + TONIC DIET METAL SIGN)            0.042028
# 616                     (BAG RED RETROSPOT, JUMBO BAG)            0.035357
# 617             (BAG PINK POLKADOT, JUMBO STORAGE BAG)            0.057372
# 601  (WOODEN PICTURE FRAME WHITE FINISH, HANGING HE...            0.051368
# 600                       (WOODEN FRAME ANTIQUE WHITE)            0.040694
# 452                     (LUNCH BAG, BAG PINK POLKADOT)            0.068712
# 449                              (LUNCH BAG CARS BLUE)            0.030687
# 279                    (LUNCH BAG VINTAGE LEAF DESIGN)            0.090727
# 278                                 (LUNCH BAG DESIGN)            0.031354
# 568                          (LUNCH BAG  BLACK SKULL.)            0.042695
# 573           (BAG RED RETROSPOT, LUNCH BAG CARS BLUE)            0.063376
# 504                   (JUMBO  BAG BAROQUE BLACK WHITE)            0.057372
# 505                     (BAG RED RETROSPOT, JUMBO BAG)            0.040694
# 301                                  (PLASTERS IN TIN)            0.051368
# 300                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.076718
#
#      consequent support   support  confidence       lift  leverage  conviction
# 316            0.031354  0.020680    0.673913  21.493525  0.019718    2.970514
# 317            0.030687  0.020680    0.659574  21.493525  0.019718    2.847357
# 321            0.036024  0.022682    0.708333  19.662809  0.021528    3.305061
# 320            0.032021  0.022682    0.629630  19.662809  0.021528    2.613542
# 323            0.031354  0.022682    0.523077  16.682815  0.021322    2.031031
# 322            0.043362  0.022682    0.723404  16.682815  0.021322    3.458613
# 319            0.038692  0.021348    0.640000  16.540690  0.020057    2.670299
# 318            0.033356  0.021348    0.551724  16.540690  0.020057    2.156361
# 312            0.046698  0.028019    0.636364  13.627273  0.025963    2.621581
# 313            0.044029  0.028019    0.600000  13.627273  0.025963    2.389927
# 179            0.056037  0.031354    0.712121  12.707973  0.028887    3.279028
# 178            0.044029  0.031354    0.559524  12.707973  0.028887    2.170312
# 173            0.048032  0.032021    0.600000  12.491667  0.029458    2.379920
# 172            0.053369  0.032021    0.666667  12.491667  0.029458    2.839893
# 607            0.036024  0.020680    0.449275  12.471551  0.019022    1.750377
# 606            0.046031  0.020680    0.574074  12.471551  0.019022    2.239754
# 221            0.054036  0.023349    0.648148  11.994742  0.021402    2.688529
# 220            0.036024  0.023349    0.432099  11.994742  0.021402    1.697436
# 174            0.053369  0.026017    0.619048  11.599405  0.023774    2.484907
# 175            0.042028  0.026017    0.487500  11.599405  0.023774    1.869214
# 164            0.048032  0.020680    0.543860  11.322856  0.018854    2.087007
# 165            0.038025  0.020680    0.430556  11.322856  0.018854    1.689321
# 609            0.036024  0.020680    0.402597  11.175806  0.018830    1.613612
# 604            0.051368  0.020680    0.574074  11.175806  0.018830    2.227224
# 304            0.051368  0.025350    0.550725  10.721250  0.022986    2.111472
# 305            0.046031  0.025350    0.493506  10.721250  0.022986    1.883478
# 614            0.040694  0.020013    0.434783  10.684248  0.018140    1.697234
# 619            0.046031  0.020013    0.491803  10.684248  0.018140    1.877165
# 608            0.025350  0.020680    0.269565  10.633638  0.018736    1.334342
# 605            0.076718  0.020680    0.815789  10.633638  0.018736    5.012103
# 599            0.075384  0.020013    0.769231  10.204221  0.018052    4.006671
# 602            0.026017  0.020013    0.265487  10.204221  0.018052    1.326025
# 296            0.076718  0.036024    0.782609  10.201134  0.032493    4.247098
# 297            0.046031  0.036024    0.469565  10.201134  0.032493    1.798467
# 183            0.042028  0.020013    0.416667   9.914021  0.017995    1.642238
# 182            0.048032  0.020013    0.476190   9.914021  0.017995    1.817393
# 616            0.057372  0.020013    0.566038   9.866169  0.017985    2.172144
# 617            0.035357  0.020013    0.348837   9.866169  0.017985    1.481416
# 601            0.040694  0.020013    0.389610   9.574196  0.017923    1.571629
# 600            0.051368  0.020013    0.491803   9.574196  0.017923    1.866664
# 452            0.030687  0.020013    0.291262   9.491347  0.017905    1.367661
# 449            0.068712  0.020013    0.652174   9.491347  0.017905    2.677452
# 279            0.031354  0.026684    0.294118   9.380476  0.023840    1.372248
# 278            0.090727  0.026684    0.851064   9.380476  0.023840    6.105118
# 568            0.063376  0.025350    0.593750   9.368750  0.022644    2.305537
# 573            0.042695  0.025350    0.400000   9.368750  0.022644    1.595508
# 504            0.040694  0.021348    0.372093   9.143729  0.019013    1.527784
# 505            0.057372  0.021348    0.524590   9.143729  0.019013    1.982770
# 301            0.076718  0.036024    0.701299   9.141276  0.032083    3.090988
# 300            0.051368  0.036024    0.469565   9.141276  0.032083    1.788405
